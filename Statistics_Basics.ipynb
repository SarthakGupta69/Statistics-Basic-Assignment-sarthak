# %% [markdown]
# ## Assignment Questions

# %% [markdown]
# Q1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss
# nominal, ordinal, interval, and ratio scales?
# - Answer In data analysis, data is generally categorized into two main types: qualitative (or categorical) and quantitative (or numerical). Understanding these types of data, as well as the different scales used to measure them, is essential for choosing the appropriate methods for analysis and interpretation.
#
# 1. Qualitative Data (Categorical Data)
# Qualitative data refers to non-numerical information that describes characteristics or qualities. This type of data is used to categorize or label variables without providing numerical values. Qualitative data can be divided into two main subtypes:
#
# Nominal Data: Nominal data is the simplest form of qualitative data. It consists of categories that have no inherent order or ranking. The categories are merely labels, and there is no meaningful way to order them.
#
# Examples of Nominal Data:
#
# Colors (red, blue, green, etc.)
#
# Gender (male, female, non-binary)
#
# Marital status (single, married, divorced)
#
# Types of fruit (apple, orange, banana)
#
# There’s no meaningful way to rank or order these categories; one is not "higher" or "lower" than the other.
#
# Ordinal Data: Ordinal data refers to categories with a meaningful order or ranking. While the categories can be arranged in a specific order, the intervals between the categories are not necessarily consistent or meaningful.
#
# Examples of Ordinal Data:
#
# Education level (high school, bachelor’s, master’s, doctorate)
#
# Rating scale (1 star, 2 stars, 3 stars, 4 stars, 5 stars)
#
# Socioeconomic status (low, middle, high)
#
# Although these categories can be ordered, the difference between adjacent categories is not uniform. For example, the difference in education level between high school and bachelor’s may not be the same as between master’s and doctorate.
#
# 2. Quantitative Data (Numerical Data)
# Quantitative data is numerical and represents quantities. This type of data can be measured and expressed in numerical terms, and it allows for mathematical operations (addition, subtraction, multiplication, division).
#
# Quantitative data is further categorized into two types based on the level of measurement:
#
# Interval Data: Interval data is numerical data where the intervals between values are consistent and meaningful, but there is no absolute zero point. This means you can measure the difference between values, but you cannot compute ratios because there’s no true zero that represents the absence of the quantity.
#
# Examples of Interval Data:
#
# Temperature in Celsius or Fahrenheit: The difference between 10°C and 20°C is the same as between 20°C and 30°C, but 0°C does not mean "no temperature."
#
# IQ scores: The difference between an IQ of 100 and 110 is the same as the difference between 110 and 120, but an IQ of 0 does not represent "no intelligence."
#
# In interval data, you can perform addition and subtraction but not meaningful multiplication or division because of the absence of a true zero.
#
# Ratio Data: Ratio data is the most advanced level of quantitative data. It has all the properties of interval data, but it also has a true zero point, which means you can compute ratios. In ratio data, zero represents the complete absence of the quantity.
#
# Examples of Ratio Data:
#
# Height: A height of 0 cm means no height at all.
#
# Weight: A weight of 0 kg means no weight.
#
# Income: An income of 0 means no income.
#
# In ratio data, you can perform all mathematical operations, including addition, subtraction, multiplication, and division. For example, a person who weighs 80 kg weighs twice as much as someone who weighs 40 kg.

# %% [markdown]
# Q2. . What are the measures of central tendency, and when should you use each? Discuss the mean, median, and mode with examples and situations where each is appropriate?
# - Answer Measures of central tendency are statistical measures that summarize a set of data by identifying the central point or typical value within a distribution. These measures provide a single value that represents the center of a dataset, helping to give a sense of the "average" or typical value in the dataset. The three primary measures of central tendency are the mean, median, and mode. Each measure is useful in different situations, depending on the nature of the data and the distribution of values.
#
# 1. Mean (Arithmetic Average)
# Definition:
# The mean is the sum of all values in a dataset divided by the number of values. It is the most commonly used measure of central tendency.
#
# Formula:
# Mean
# =
# ∑
# 𝑋
# 𝑁
# Mean=
# N
# ∑X
# ​
#
# Where:
#
# ∑
# 𝑋
# ∑X is the sum of all data points.
#
# 𝑁
# N is the number of data points.
#
# Example:
# For the data set: 5, 10, 15, 20, 25
#
# Mean
# =
# 5
# +
# 10
# +
# 15
# +
# 20
# +
# 25
# 5
# =
# 75
# 5
# =
# 15
# Mean=
# 5
# 5+10+15+20+25
# ​
#  =
# 5
# 75
# ​
#  =15
# So, the mean is 15.
#
# When to Use the Mean:
# The mean is appropriate for interval and ratio data that do not have extreme outliers.
#
# It is especially useful when the data is normally distributed (i.e., it has a bell-shaped curve), as the mean represents the balance point of the distribution.
#
# The mean is sensitive to outliers. If the data contains extreme values, the mean might not accurately reflect the center of the data.
#
# Example Situation:
# Test Scores: In a class of students, calculating the average test score (mean) is appropriate if the data is fairly uniform and there are no extreme outliers (e.g., a student scoring 0 or 1000).
#
# 2. Median (Middle Value)
# Definition:
# The median is the middle value in a dataset when the values are arranged in numerical order. If there is an even number of values, the median is the average of the two middle values.
#
# Example:
# For the data set: 5, 10, 15, 20, 25
#
# The values are already in numerical order.
#
# The middle value is 15, so the median is 15.
#
# For the data set: 5, 10, 15, 20
#
# When arranged in order: 5, 10, 15, 20.
#
# The median is the average of the two middle values:
# 10
# +
# 15
# 2
# =
# 12.5
# 2
# 10+15
# ​
#  =12.5.
#
# When to Use the Median:
# The median is particularly useful when the data contains outliers or is skewed (i.e., not symmetrically distributed). Unlike the mean, the median is not affected by extreme values.
#
# The median is appropriate for ordinal, interval, and ratio data.
#
# It is best used when you want a central value that is not distorted by outliers or extreme values.
#
# Example Situation:
# Income Data: If you're calculating the average income of a group of people, and there are a few extremely high earners, using the median (instead of the mean) will give you a better idea of what a "typical" income is, since the median is not skewed by extreme values.
#
# 3. Mode (Most Frequent Value)
# Definition:
# The mode is the value that appears most frequently in a dataset. A dataset can have more than one mode (bimodal, multimodal) or no mode at all if no value repeats.
#
# Example:
# For the data set: 5, 10, 15, 20, 20, 25
#
# The mode is 20, because it appears more frequently than any other value.
#
# For the data set: 5, 10, 15, 20, 25
#
# There is no mode, since no value repeats.
#
# When to Use the Mode:
# The mode is useful for nominal data (categorical data), where you want to know which category appears most frequently.
#
# It is also used when dealing with multimodal distributions, where there are multiple peaks or most frequent values.
#
# The mode can be used for ordinal, interval, and ratio data when the goal is to identify the most common value.
# When to Use Each Measure:
# Use the Mean when:
#
# The data is normally distributed.
#
# The data does not have outliers or extreme values.
#
# You are working with interval or ratio data.
#
# Use the Median when:
#
# The data is skewed or contains outliers.
#
# You want to find the middle value in a dataset.
#
# You are working with ordinal, interval, or ratio data.
#
# Use the Mode when:
#
# You are dealing with nominal data (e.g., categories or labels).
#
# You want to find the most frequent category.
#
# The data may be multimodal (i.e., more than one value appears most frequently).
#
# Practical Example for Each Measure:
# Mean:
#
# Test Scores: You might calculate the mean score to get the "average" score in a class, assuming the scores are fairly uniform and not heavily influenced by outliers.
#
# Median:
#
# Income Distribution: If you're analyzing income levels in a city and there are a few extremely wealthy individuals, the median would give a better sense of the "typical" income compared to the mean.
#
# Mode:
#
# Most Popular Pet: In a survey of 100 people about their favorite pet, if 40 people chose dogs and 30 chose cats, the mode would be "dogs" because it is the most frequently chosen response.

# %% [markdown]
# Q3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
# - Answer Dispersion refers to the extent to which the values in a dataset differ from the central value (usually the mean). It is a measure of the spread or variability of the data points, indicating how much the data points deviate from the mean or median. Dispersion helps to understand how consistent or inconsistent the values are within a dataset.
#
# The two most common measures of dispersion are variance and standard deviation. Both provide insight into the spread of the data, but they do so in different ways. Let's explore these concepts in more detail.
#
# 1. Variance
# Variance measures the average squared deviation from the mean. In other words, it gives an indication of how far each data point is from the mean, but it uses the squared differences to avoid the issue of negative differences canceling out positive ones.
#
# Formula for Variance (Population):
# For a population with
# 𝑁
# N data points, the variance
# 𝜎
# 2
# σ
# 2
#   is calculated as:
#
# 𝜎
# 2
# =
# 1
# 𝑁
# ∑
# 𝑖
# =
# 1
# 𝑁
# (
# 𝑥
# 𝑖
# −
# 𝜇
# )
# 2
# σ
# 2
#  =
# N
# 1
# ​
#
# i=1
# ∑
# N
# ​
#  (x
# i
# ​
#  −μ)
# 2
#
# Where:
#
# 𝑥
# 𝑖
# x
# i
# ​
#   = individual data points
#
# 𝜇
# μ = mean of the data
#
# 𝑁
# N = number of data points
#
# Formula for Sample Variance:
# When working with a sample of data rather than an entire population, the formula is adjusted by using
# 𝑁
# −
# 1
# N−1 (called Bessel's correction) instead of
# 𝑁
# N to provide an unbiased estimate of the population variance:
#
# 𝑠
# 2
# =
# 1
# 𝑁
# −
# 1
# ∑
# 𝑖
# =
# 1
# 𝑁
# (
# 𝑥
# 𝑖
# −
# 𝑥
# ˉ
# )
# 2
# s
# 2
#  =
# N−1
# 1
# ​
#
# i=1
# ∑
# N
# ​
#  (x
# i
# ​
#  −
# x
# ˉ
#  )
# 2
#
# Where:
#
# 𝑥
# 𝑖
# x
# i
# ​
#   = individual data points
#
# 𝑥
# ˉ
# x
# ˉ
#   = sample mean
#
# 𝑁
# −
# 1
# N−1 = degrees of freedom (sample size minus 1)
#
# Interpretation of Variance:
# Variance represents the average squared deviation from the mean. A larger variance indicates that the data points are more spread out, while a smaller variance suggests that the data points are closer to the mean.
#
# However, since variance is in squared units (e.g., squared meters, squared dollars), it is not as intuitively easy to interpret as the original data values.
#
# 2. Standard Deviation
# The standard deviation is the square root of the variance and provides a measure of spread in the same units as the original data, making it easier to interpret than variance.
#
# Formula for Standard Deviation (Population):
# 𝜎
# =
# 𝜎
# 2
# =
# 1
# 𝑁
# ∑
# 𝑖
# =
# 1
# 𝑁
# (
# 𝑥
# 𝑖
# −
# 𝜇
# )
# 2
# σ=
# σ
# 2
#
# ​
#  =
# N
# 1
# ​
#
# i=1
# ∑
# N
# ​
#  (x
# i
# ​
#  −μ)
# 2
#
# ​
#
# Formula for Sample Standard Deviation:
# 𝑠
# =
# 𝑠
# 2
# =
# 1
# 𝑁
# −
# 1
# ∑
# 𝑖
# =
# 1
# 𝑁
# (
# 𝑥
# 𝑖
# −
# 𝑥
# ˉ
# )
# 2
# s=
# s
# 2
#
# ​
#  =
# N−1
# 1
# ​
#
# i=1
# ∑
# N
# ​
#  (x
# i
# ​
#  −
# x
# ˉ
#  )
# 2
#
# ​
#
# Interpretation of Standard Deviation:
# The standard deviation gives an idea of the average distance that each data point is from the mean. If the standard deviation is small, it means that the data points tend to be close to the mean. A large standard deviation means that the data points are spread out over a wide range of values.
#
# A small standard deviation: The data points are clustered closely around the mean.
#
# A large standard deviation: The data points are more spread out from the mean.
#
# Since the standard deviation is in the same units as the original data, it is more interpretable and commonly used to describe variability.
#
# How Variance and Standard Deviation Measure the Spread of Data
# Variance:
#
# Variance quantifies the degree of spread in the dataset by measuring how far the values deviate from the mean, but it weights larger deviations more heavily due to the squaring of differences. It is useful in statistical models and analysis, especially when working with sums of squared deviations.
#
# Example: If you have two datasets of exam scores:
#
# Dataset A: 85, 90, 95, 100
#
# Dataset B: 60, 80, 90, 100
#
# Both datasets have the same mean (92.5), but the spread in Dataset B is larger. The variance calculation would show that Dataset B has a higher variance, reflecting the greater spread of data points.
#
# Standard Deviation:
#
# The standard deviation is essentially a "normalized" version of variance, making it easier to understand the typical deviation from the mean in the original units.
#
# Example: Continuing with the two datasets above, Dataset A has a smaller standard deviation than Dataset B, indicating that the scores in Dataset A are more consistently close to the mean (92.5).
#
# Visualizing Dispersion:
# You can visualize the dispersion of a dataset using boxplots or histograms:
#
# A boxplot shows the spread of the data and highlights the interquartile range, where most of the data lies.
#
# A histogram shows the distribution of the data and can visually reveal the presence of outliers or skewed distributions.
#
# In both cases, datasets with greater dispersion will have wider spread, while those with lesser dispersion will have values clustered more tightly around the central value.
#
# When to Use Variance vs. Standard Deviation
# Variance is useful for theoretical statistical analysis, especially when comparing different datasets or performing operations like ANOVA (Analysis of Variance).
#
# Standard Deviation is more commonly used for practical, real-world interpretation because it provides a more intuitive measure of the spread of the data in the same units as the original data.

# %% [markdown]
# Q4. What is a box plot, and what can it tell you about the distribution of data?
# - Answer A box plot, also known as a box-and-whisker plot, is a graphical representation of the distribution of a dataset. It visually summarizes key statistical measures, such as the median, quartiles, and potential outliers, providing a clear and concise way to assess the spread and shape of the data.
#
# Components of a Box Plot
# A typical box plot consists of several key elements:
#
# Box:
#
# The central rectangular box represents the interquartile range (IQR), which contains the middle 50% of the data. The edges of the box are the first quartile (Q1) and the third quartile (Q3), also known as the lower and upper quartiles.
#
# The width of the box shows the spread of the middle 50% of the data.
#
# Median:
#
# The line inside the box represents the median (also called the second quartile, Q2), which is the middle value of the data when it is ordered.
#
# The median divides the data into two equal halves.
#
# Whiskers:
#
# The lines extending from the box are called whiskers. They represent the range of the data, extending to the smallest and largest data points that are within a certain distance from the box (usually 1.5 times the IQR).
#
# The whiskers show the minimum and maximum values within this range.
#
# Outliers:
#
# Any data points outside the range of the whiskers are considered outliers. These are plotted as individual points outside the whiskers.
#
# Outliers are usually defined as data points that are greater than 1.5 times the IQR above the third quartile or below the first quartile.
#
# How to Read a Box Plot
# A box plot can provide several important insights into the distribution of the data:
#
# Symmetry of the Data: If the median is approximately centered inside the box, the data is likely symmetrical. If the median is skewed toward one end of the box, it suggests a skewed distribution.
#
# Spread of the Data: The length of the box and the whiskers shows the spread or variability of the data.
#
# A narrow box and short whiskers suggest that the data is concentrated around the median (low spread).
#
# A wide box and long whiskers indicate a wider spread of data (high variability).
#
# Skewness:
#
# If the right whisker (above the median) is longer than the left whisker, the data is positively skewed (skewed to the right).
#
# If the left whisker (below the median) is longer than the right whisker, the data is negatively skewed (skewed to the left).
#
# Outliers: Box plots help identify potential outliers, which are data points that fall outside the range of the whiskers. These outliers might indicate unusual or exceptional values that could require further investigation.
#
# What a Box Plot Can Tell You About the Distribution of Data
# Central Tendency (Median): The median line inside the box represents the central value of the data. This helps you understand the "typical" value of the dataset.
#
# Spread (Interquartile Range): The box shows the interquartile range (IQR), which is the range between the first quartile (Q1) and the third quartile (Q3). The IQR represents the middle 50% of the data and provides a sense of how spread out the values are in that middle range.
#
# Skewness: By looking at the relative positions of the median and the whiskers, you can determine if the data is:
#
# Symmetrical (if the median is centered in the box and the whiskers are roughly equal in length),
#
# Positively skewed (if the upper whisker is longer than the lower whisker, indicating that there are more higher values),
#
# Negatively skewed (if the lower whisker is longer than the upper whisker, indicating that there are more lower values).
#
# Outliers: Points outside the whiskers are considered outliers. These outliers are potential data points that are unusually high or low compared to the rest of the dataset.
#
# Example:
# Consider a dataset of the ages of a group of people:
#
# Data: 22, 25, 28, 30, 31, 35, 37, 40, 41, 43, 45, 50, 55
#
# A box plot for this data might look like this:
#
# mathematica
# Copy
#     |-----|---------|-----|--------|----|---------|
#   Min   Q1         Median   Q3         Max
# Q1 (First Quartile): 28
#
# Median: 35
#
# Q3 (Third Quartile): 43
#
# Min: 22
#
# Max: 55
#
# In this example:
#
# The data is likely symmetrical, as the median is centered between Q1 and Q3, and the whiskers are of roughly equal length.
#
# The spread of data is between 22 and 55, with the interquartile range (IQR) being between 28 and 43.
#
# There are no outliers because all the data points lie within the whiskers.
#
# Advantages of Box Plots
# Simplicity: Box plots provide a clear summary of key statistics (median, quartiles, range, and potential outliers) in a compact and easy-to-understand graphical format.
#
# Comparison: You can compare multiple datasets by placing their box plots side by side, which makes it easy to see differences in distribution, spread, and central tendency.
#
# Detection of Skewness and Outliers: Box plots help easily identify if the data is skewed and whether any outliers exist, making them useful for data exploration.
#
# Limitations of Box Plots
# No Detailed Shape Information: Box plots provide a high-level summary but do not show the exact shape of the distribution (e.g., whether it is bimodal, normal, etc.).
#
# Data Precision: Box plots do not show the individual data points (unless you use dot plots or add individual points overlaid on the box plot). This makes it difficult to see specific patterns in the data.

# %% [markdown]
# Q5.  Discuss the role of random sampling in making inferences about populations?
# - Answer Random sampling plays a crucial role in making inferences about populations because it ensures that the sample is representative of the entire population. In statistical analysis, we often cannot measure or collect data from an entire population, so we rely on samples to make conclusions or predictions about the population as a whole.
#
# The goal of random sampling is to select a subset of the population in such a way that each individual has an equal chance of being selected, minimizing biases and providing a solid foundation for valid inferences.
#
# Let's break down why random sampling is important for making inferences about populations:
#
# 1. Representativeness
# In order for a sample to provide useful insights into a population, it must reflect the key characteristics of the population. Random sampling helps achieve this by giving all members of the population an equal chance to be included, thereby reducing the likelihood of selecting a non-representative sample.
#
# For example, if you're studying the average income of a city's residents, you want your sample to include a broad range of income levels to ensure that the sample is reflective of the city's diverse population. Random sampling helps avoid selecting only a certain type of person (e.g., only wealthy individuals), which would lead to inaccurate conclusions.
#
# 2. Reduces Bias
# Bias in sampling occurs when certain individuals or groups within the population are more likely to be selected than others. This can lead to skewed or inaccurate results.
#
# Random sampling minimizes bias because each individual in the population has an equal chance of being selected, preventing overrepresentation or underrepresentation of any specific subgroup. By reducing bias, random sampling helps ensure that the sample more closely mirrors the diversity and variation present in the entire population.
#
# For example, if you want to survey students in a school but only survey those in advanced classes, this would introduce bias. Random sampling ensures you capture a more representative view of the entire student body, including all performance levels.
#
# 3. Basis for Statistical Inference
# Statistical inference involves drawing conclusions about a population based on sample data. Since it's impractical or impossible to measure an entire population, random sampling allows you to use a sample to estimate population parameters (such as means, proportions, etc.) and make predictions or generalizations about the population as a whole.
#
# Inferential statistics rely on the assumption that the sample accurately represents the population. Random sampling ensures that the sample is an unbiased representation, which allows you to apply inferential statistical methods (such as confidence intervals and hypothesis testing) to make reliable conclusions about the population.
#
# 4. Enables Generalization
# One of the main goals of random sampling is to allow for the generalization of findings. If the sample is random, any patterns or characteristics observed in the sample are likely to be true for the entire population (within a certain margin of error).
#
# For example, in a political poll where random sampling is used, if 60% of the sample favors a particular candidate, we can infer with a certain level of confidence that around 60% of the entire population holds the same view (again, considering margin of error).
#
# 5. Validates the Use of Probability Theory
# Random sampling provides the foundation for applying probability theory in statistics. Because the sample is chosen randomly, we can use probability models to estimate how likely our sample is to accurately reflect the population. This underpins methods like:
#
# Confidence intervals: Ranges of values within which the true population parameter is likely to fall, with a known probability.
#
# Hypothesis testing: Statistical tests to determine whether observed data from the sample supports a certain hypothesis about the population.
#
# 6. Avoiding Systematic Errors
# Systematic errors occur when there is a consistent, predictable bias introduced into the sample (e.g., always surveying a certain demographic group or using a flawed sampling method). These errors can lead to misleading results.
#
# Random sampling helps avoid systematic errors by ensuring that no particular group or characteristic is disproportionately selected. This randomness ensures that all possible outcomes have a fair chance of being represented in the sample, leading to more accurate and reliable inferences.
#
# 7. Flexibility in Analysis
# Random sampling provides the flexibility to apply various statistical techniques, such as:
#
# Descriptive statistics: Summarizing and describing the data (e.g., calculating the mean, median, variance).
#
# Inferential statistics: Making generalizations about the population (e.g., estimating population parameters, testing hypotheses).
#
# Because the sample is representative, we can confidently apply these techniques to draw conclusions about the population's characteristics and make informed decisions.
#
# Types of Random Sampling
# There are different methods of random sampling, each with its specific advantages depending on the nature of the population and research objectives:
#
# Simple Random Sampling:
#
# Every member of the population has an equal chance of being selected. This is the most basic form of random sampling and is effective for homogenous populations.
#
# Stratified Random Sampling:
#
# The population is divided into distinct subgroups (strata) (e.g., age groups, income levels), and random samples are drawn from each subgroup. This is useful when certain subgroups within the population are expected to behave differently and ensures that these subgroups are adequately represented in the sample.
#
# Systematic Random Sampling:
#
# After randomly selecting a starting point, every
# 𝑘
# k-th member of the population is selected. For example, if the population consists of 1000 individuals, and you want a sample of 100, you might select every 10th individual after randomly choosing a starting point.
#
# Cluster Sampling:
#
# The population is divided into clusters (e.g., geographic regions or institutions), and a random sample of clusters is selected. All individuals within the selected clusters are then surveyed. This is efficient when the population is geographically dispersed or hard to access.
#
# Multistage Sampling:
#
# A combination of different sampling methods, often used when a population is large or geographically spread out. For example, you might use cluster sampling to select regions, and then within those regions, use stratified sampling to select individuals.

# %% [markdown]
# Q6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
# - Answer Skewness refers to the asymmetry or lack of symmetry in the distribution of data. In a perfectly symmetrical distribution, the left and right sides of the data are mirror images of each other. Skewness describes the extent to which a distribution deviates from this symmetry. It tells us if the data is "tilted" to one side, and in which direction. Skewness can have a significant impact on how data is interpreted and analyzed, as it affects measures like the mean, median, and mode, and it influences statistical methods that assume normality.
#
# Types of Skewness
# There are three main types of skewness:
#
# Positive Skew (Right Skew)
#
# In a positively skewed distribution, the tail of the distribution extends more to the right (the larger values).
#
# The majority of the data points are clustered on the left, with a few larger values stretching the distribution to the right.
#
# The mean is typically greater than the median, which in turn is greater than the mode.
#
# Example: Income distribution is often positively skewed because most people earn moderate incomes, but a few individuals have very high incomes.
#
# Characteristics of positive skew:
#
# The right tail is longer or fatter.
#
# The mean is larger than the median.
#
# The mode is typically less than the median, and the median is less than the mean.
#
# Negative Skew (Left Skew)
#
# In a negatively skewed distribution, the tail of the distribution extends more to the left (the smaller values).
#
# The majority of the data points are clustered on the right, with a few smaller values stretching the distribution to the left.
#
# The mean is typically less than the median, which in turn is less than the mode.
#
# Example: Age at retirement can often exhibit negative skew, where most people retire in their 60s or 70s, but a few retire much earlier in life.
#
# Characteristics of negative skew:
#
# The left tail is longer or fatter.
#
# The mean is smaller than the median.
#
# The mode is typically greater than the median, and the median is greater than the mean.
#
# Symmetrical Distribution (Zero Skewness)
#
# When the data is symmetrical, there is no skewness, and the mean, median, and mode are all equal.
#
# A perfectly normal distribution is an example of a distribution with zero skewness.
#
# Example: Heights of adults in a specific population might be close to a normal distribution (symmetrical).
#
# Characteristics of symmetrical distributions:
#
# The distribution looks the same on both sides of the center.
#
# The mean, median, and mode all coincide at the center.
#
# How Skewness Affects the Interpretation of Data
# Skewness has important implications for data interpretation and statistical analysis:
#
# Impact on Central Tendency (Mean, Median, Mode)
#
# Skewness affects the relationship between the mean, median, and mode:
#
# In a positively skewed distribution, the mean is greater than the median, and the median is greater than the mode.
#
# In a negatively skewed distribution, the mean is less than the median, and the median is greater than the mode.
#
# In a symmetric distribution, all three measures are equal.
#
# The mean is more sensitive to extreme values (outliers) than the median. This means that in a skewed distribution, the mean may not accurately represent the "typical" value, whereas the median might provide a better measure of central tendency.
#
# Example: In a positively skewed dataset of salaries, the mean salary might be higher than what most employees actually earn, as the high earners (outliers) pull the mean upward. The median salary, however, may more accurately reflect the salary of the "typical" employee.
#
# Impact on Data Analysis and Statistical Tests
#
# Many statistical tests, such as t-tests and ANOVA, assume that the data follows a normal distribution (i.e., zero skewness). If the data is significantly skewed, the assumptions of these tests may be violated, leading to inaccurate or misleading results.
#
# In such cases, data transformations (like the log transformation or square root transformation) might be applied to reduce skewness and make the data more normal, allowing these statistical tests to be more valid.
#
# Outliers and Skewness
#
# Skewness can also indicate the presence of outliers. For instance, if there is a long tail on one side of the distribution, it may suggest that there are outlier data points that need to be addressed in the analysis.
#
# Positive skew: A few extreme high values (outliers) can stretch the tail to the right.
#
# Negative skew: A few extreme low values (outliers) can stretch the tail to the left.
#
# Impact on Visualizations
#
# Histograms and box plots can reveal skewness in the data visually:
#
# A right-skewed (positive skew) histogram will have a long tail extending to the right, and the box plot will have a longer right whisker.
#
# A left-skewed (negative skew) histogram will have a long tail extending to the left, and the box plot will have a longer left whisker.
#
# Interpreting Skewness in Real-World Data
#
# Positive skew suggests that the distribution is concentrated on the lower end, with a few larger values extending the tail. It is common in data where there are a few extreme high values, such as income, wealth, and property prices.
#
# Negative skew suggests that the distribution is concentrated on the higher end, with a few smaller values extending the tail. This can be seen in data like age at retirement or test scores where most people perform well, but a few perform poorly.

# %% [markdown]
# Q7. What is the interquartile range (IQR), and how is it used to detect outliers?
# - Answer The Interquartile Range (IQR) is a measure of statistical dispersion, which describes the spread of the middle 50% of values in a dataset. It is calculated as the difference between the third quartile (Q3) and the first quartile (Q1):
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
# Quartiles Overview
# Q1 (First Quartile): This is the median of the lower half of the data (i.e., the 25th percentile). It marks the point below which 25% of the data falls.
#
# Q2 (Second Quartile): This is the median of the dataset, which divides the data into two equal halves (50th percentile).
#
# Q3 (Third Quartile): This is the median of the upper half of the data (i.e., the 75th percentile). It marks the point below which 75% of the data falls.
#
# The IQR represents the range within which the central 50% of the data lies. Since it focuses on the middle portion of the data, it is less affected by extreme outliers, making it a useful measure of spread in skewed or non-normal distributions.
#
# How to Calculate the IQR
# Sort the data in ascending order.
#
# Find Q1 (25th percentile): This is the median of the lower half of the dataset.
#
# Find Q3 (75th percentile): This is the median of the upper half of the dataset.
#
# Calculate the IQR: Subtract Q1 from Q3:
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
# Using the IQR to Detect Outliers
# Outliers are data points that are significantly different from the rest of the data. A common method for detecting outliers uses the IQR and defines outliers as values that lie outside a certain range calculated from the quartiles.
#
# Outlier Detection Rule:
# Calculate the lower bound for outliers:
#
# Lower Bound
# =
# 𝑄
# 1
# −
# 1.5
# ×
# IQR
# Lower Bound=Q1−1.5×IQR
# Calculate the upper bound for outliers:
#
# Upper Bound
# =
# 𝑄
# 3
# +
# 1.5
# ×
# IQR
# Upper Bound=Q3+1.5×IQR
# Identify outliers:
#
# Any data point below the lower bound or above the upper bound is considered an outlier.
#
# This rule is based on the idea that most of the data lies within 1.5 times the IQR from the quartiles. Values outside of this range are considered unusual or extreme.
#
# Why 1.5x IQR?
# The factor of 1.5 is a standard threshold used in statistics for identifying outliers, and it balances sensitivity with practicality. Values that are more than 1.5 times the IQR away from the quartiles are considered far enough from the central data to warrant being labeled as potential outliers. The choice of 1.5 is somewhat arbitrary but is widely accepted in statistical analysis.
#
# Example:
# Let’s use an example dataset to illustrate how the IQR and outlier detection works:
#
# Data: 5, 7, 8, 12, 15, 18, 19, 21, 24, 35, 40
#
# Sort the data: The data is already sorted: 5, 7, 8, 12, 15, 18, 19, 21, 24, 35, 40.
#
# Find Q1 (25th percentile): The lower half of the data is: 5, 7, 8, 12, 15. The median of this subset is 8. So, Q1 = 8.
#
# Find Q3 (75th percentile): The upper half of the data is: 18, 19, 21, 24, 35, 40. The median of this subset is 24. So, Q3 = 24.
#
# Calculate the IQR:
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# =
# 24
# −
# 8
# =
# 16
# IQR=Q3−Q1=24−8=16
# Calculate the lower bound:
#
# Lower Bound
# =
# 𝑄
# 1
# −
# 1.5
# ×
# IQR
# =
# 8
# −
# 1.5
# ×
# 16
# =
# 8
# −
# 24
# =
# −
# 16
# Lower Bound=Q1−1.5×IQR=8−1.5×16=8−24=−16
# Since no data points are below -16, there are no outliers on the low end.
#
# Calculate the upper bound:
#
# Upper Bound
# =
# 𝑄
# 3
# +
# 1.5
# ×
# IQR
# =
# 24
# +
# 1.5
# ×
# 16
# =
# 24
# +
# 24
# =
# 48
# Upper Bound=Q3+1.5×IQR=24+1.5×16=24+24=48
# Since 40 is less than 48, there are no outliers on the high end either.
#
# Interpretation of Results:
# In this example, there are no outliers since all data points fall within the range of -16 to 48.
#
# Box Plot and Outliers
# A box plot is often used to visualize the IQR and detect outliers. In a box plot:
#
# The box spans from Q1 to Q3 (the IQR).
#
# The whiskers extend to the lowest and highest values within the 1.5 IQR range.
#
# Any points outside the whiskers are plotted individually and considered outliers.

# %% [markdown]
# Q8. Discuss the conditions under which the binomial distribution is used?
# - Answer The binomial distribution is used to model the number of successes in a fixed number of independent trials, where each trial has two possible outcomes (often labeled as "success" or "failure"). This distribution is widely used in statistics and probability theory because it fits situations where the process involves repeating a simple experiment multiple times under certain conditions.
#
# The conditions under which the binomial distribution is used are:
# 1. Fixed Number of Trials (n)
# The experiment is repeated a fixed number of times, denoted by n.
#
# Each trial is independent of the others.
#
# For example, you might flip a coin 10 times, where the number of trials is fixed at 10.
#
# 2. Two Possible Outcomes (Success/Failure)
# Each trial has only two possible outcomes: one is considered a "success" and the other a "failure".
#
# The outcomes can be anything that fits this binary classification, such as:
#
# Success or failure on a test
#
# Heads or tails on a coin flip
#
# Yes or no answers in a survey
#
# 3. Constant Probability of Success (p)
# The probability of success (denoted by p) is constant across all trials.
#
# This means that in each trial, the probability of success does not change.
#
# For example, in a coin flip, the probability of getting heads (success) is always 0.5.
#
# 4. Independence of Trials
# The trials are independent, meaning the outcome of one trial does not affect the outcome of another.
#
# For instance, the outcome of one coin flip does not influence the outcome of the next coin flip.
#
# 5. The Number of Successes is What’s Being Counted
# The binomial distribution counts the number of successes in n independent trials.
#
# The random variable represents the number of successes (typically denoted by X), which can take values from 0 to n.
#
# Mathematical Formulation:
# The probability mass function (PMF) of the binomial distribution is given by the formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Where:
#
# n = number of trials
#
# k = number of successes (where
# 𝑘
# =
# 0
# ,
# 1
# ,
# 2
# ,
# .
# .
# .
# ,
# 𝑛
# k=0,1,2,...,n)
#
# p = probability of success on a single trial
#
# 1 - p = probability of failure on a single trial
#
# (
# 𝑛
# 𝑘
# )
# (
# k
# n
# ​
#  ) = binomial coefficient, representing the number of ways to choose k successes from n trials, calculated as:
#
# (
# 𝑛
# 𝑘
# )
# =
# 𝑛
# !
# 𝑘
# !
# (
# 𝑛
# −
# 𝑘
# )
# !
# (
# k
# n
# ​
#  )=
# k!(n−k)!
# n!
# ​
#
# Examples of Binomial Distribution Use:
# Coin Flips:
#
# If you flip a coin 10 times, the probability of getting exactly 6 heads (successes) out of 10 flips can be modeled using the binomial distribution. Here, n = 10, p = 0.5 (since the coin is fair), and k = 6.
#
# Quality Control in Manufacturing:
#
# Suppose a factory produces light bulbs, and the probability of a light bulb being defective is 0.05. If 100 light bulbs are randomly selected for inspection, the number of defective bulbs in the sample follows a binomial distribution. Here, n = 100, p = 0.05, and we are interested in the probability of finding a specific number of defective bulbs.
#
# Survey Responses:
#
# In a survey of 500 people, the probability that a person responds "yes" to a particular question (success) is 0.7. The number of "yes" responses in the survey follows a binomial distribution. Here, n = 500, p = 0.7, and we may want to know the probability of getting exactly 350 "yes" responses.
#
# Drug Efficacy Testing:
#
# In a clinical trial with 100 patients, the probability of a patient responding positively to a treatment is 0.8. The number of patients who respond positively can be modeled using a binomial distribution, where n = 100 and p = 0.8.
#
# When Not to Use the Binomial Distribution:
# The binomial distribution is not appropriate when the conditions mentioned above are not met. For example:
#
# If the probability of success changes from trial to trial, the binomial distribution is not applicable. In this case, you would need to use other distributions, such as the Poisson distribution or negative binomial distribution.
#
# If the trials are not independent (e.g., in cases where the outcome of one trial affects the next), the binomial model does not apply.
#
# If the number of trials is not fixed or if there are more than two possible outcomes in each trial, the binomial distribution would not be suitable.

# %% [markdown]
# Q9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule)?
# - Answer Properties of the Normal Distribution
# The normal distribution is one of the most important and widely used distributions in statistics. It is characterized by several key properties that make it extremely useful for modeling real-world data, especially when the data tends to cluster around a central value.
#
# 1. Symmetry
# The normal distribution is symmetric about its mean. This means that the left and right halves of the distribution are mirror images of each other.
#
# The mean, median, and mode are all located at the same point in a perfectly normal distribution.
#
# The shape of the normal distribution is bell-shaped, with the highest point at the mean.
#
# 2. Bell-Shaped Curve
# The distribution forms a bell-shaped curve, where most of the data points are concentrated near the mean, and fewer data points are found as you move away from the mean.
#
# 3. Defined by Two Parameters: Mean and Standard Deviation
# The mean (μ) defines the location of the center of the graph. It is the average of all the data points.
#
# The standard deviation (σ) determines the spread or width of the distribution. A larger standard deviation results in a wider distribution, while a smaller standard deviation results in a narrower distribution.
#
# The mean and standard deviation are sufficient to describe a normal distribution completely, making it a 2-parameter family of distributions.
#
# 4. 68-95-99.7 Rule (Empirical Rule)
# This rule provides a quick way to understand the spread of data in a normal distribution. It describes the percentage of data that lies within certain distances (measured in standard deviations) from the mean.
#
# In a normal distribution:
#
# 68% of the data falls within 1 standard deviation of the mean.
#
# 95% of the data falls within 2 standard deviations of the mean.
#
# 99.7% of the data falls within 3 standard deviations of the mean.
#
# This rule is useful for understanding how data is distributed around the mean and for making predictions about the likelihood of different outcomes.
#
# 5. Tails Approach Zero
# The tails of a normal distribution curve extend infinitely in both directions, approaching but never quite reaching zero. This means that extreme values are theoretically possible, but their likelihood decreases exponentially as they move further from the mean.
#
# 6. Probability Density Function (PDF)
# The probability density function (PDF) of a normal distribution is given by the formula:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝜎
# 2
# 𝜋
# 𝑒
# −
# 1
# 2
# (
# 𝑥
# −
# 𝜇
# 𝜎
# )
# 2
# f(x)=
# σ
# 2π
# ​
#
# 1
# ​
#  e
# −
# 2
# 1
# ​
#  (
# σ
# x−μ
# ​
#  )
# 2
#
#
# Where:
#
# 𝑥
# x is the variable,
#
# 𝜇
# μ is the mean,
#
# 𝜎
# σ is the standard deviation,
#
# 𝑒
# e is Euler's number (approximately 2.718).
#
# This function defines the shape of the bell curve and gives the probability of observing a particular value or range of values.
#
# 7. Area Under the Curve Represents Probabilities
# The total area under the curve of a normal distribution is equal to 1. This area represents the total probability of all outcomes. Any particular range of values can be found by calculating the area under the curve between those values.
#
# 8. Asymptotic Behavior
# The normal distribution curve approaches the horizontal axis but never actually touches it. This means that even very large or small values are possible, although their probability of occurrence is extremely low.
#
# The Empirical Rule (68-95-99.7 Rule)
# The Empirical Rule, also known as the 68-95-99.7 Rule, applies specifically to normal distributions. It states that:
#
# 68% of the data lies within 1 standard deviation of the mean (
# 𝜇
# ±
# 1
# 𝜎
# μ±1σ).
#
# 95% of the data lies within 2 standard deviations of the mean (
# 𝜇
# ±
# 2
# 𝜎
# μ±2σ).
#
# 99.7% of the data lies within 3 standard deviations of the mean (
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ).
#
# This rule is particularly useful for quickly understanding the spread and variation in normally distributed data. It allows us to make predictions about the probability of a data point falling within a specific range of values.
#
# Visualizing the Empirical Rule
# Consider a normal distribution with a mean of 0 and a standard deviation of 1. The curve would look something like this:
#
# 68% of the data falls between -1 and 1.
#
# 95% of the data falls between -2 and 2.
#
# 99.7% of the data falls between -3 and 3.
#
# This means that the vast majority of values in a normal distribution will lie within 3 standard deviations of the mean.
#
# Example of Using the Empirical Rule:
# Imagine that a factory produces light bulbs, and the lifespan of the bulbs follows a normal distribution with a mean of 1000 hours and a standard deviation of 50 hours. According to the empirical rule:
#
# 68% of the bulbs will last between 950 hours and 1050 hours (1 standard deviation from the mean).
#
# 95% of the bulbs will last between 900 hours and 1100 hours (2 standard deviations from the mean).
#
# 99.7% of the bulbs will last between 850 hours and 1150 hours (3 standard deviations from the mean).
#
# Thus, if you want to know the probability that a bulb lasts less than 950 hours, you can immediately conclude that about 34% of bulbs will last less than 950 hours, because 68% fall within 1 standard deviation above and below the mean, leaving 32% of the distribution to be split equally between the lower and upper tails.
#
# Importance of the Empirical Rule
# Quick Assessment: The Empirical Rule offers a quick way to assess how data is spread around the mean in a normal distribution.
#
# Probability Estimation: It allows for easy estimation of probabilities of outcomes without needing to perform complex calculations.
#
# Data Consistency: It helps in understanding the consistency and variation in data, making it easier to identify outliers or unusual values that fall outside the 99.7% range.
#
# Summary of the Normal Distribution and the Empirical Rule
# Normal Distribution:
#
# Symmetric, bell-shaped curve.
#
# Defined by the mean (μ) and standard deviation (σ).
#
# The mean, median, and mode are the same and located at the center of the distribution.
#
# Tails extend infinitely but never touch the axis.
#
# The area under the curve is 1, representing the total probability.
#
# Empirical Rule (68-95-99.7 Rule):
#
# 68% of the data is within 1 standard deviation of the mean.
#
# 95% of the data is within 2 standard deviations of the mean.
#
# 99.7% of the data is within 3 standard deviations of the mean.
#
# The normal distribution and the empirical rule provide foundational concepts for analyzing and understanding data in fields ranging from biology to economics to engineering.

# %% [markdown]
# Q10.Provide a real-life example of a Poisson process and calculate the probability for a specific event?
# - Answer Real-Life Example of a Poisson Process:
# A Poisson process is used to model the occurrence of events that happen randomly and independently over a fixed interval of time or space. The events must happen at a constant average rate.
#
# Example: Call Center (Customer Arrivals)
# Let's say a customer support call center receives an average of 5 calls per hour. We want to model the number of calls that arrive in a given hour and calculate the probability of receiving exactly 3 calls in an hour.
#
# This is a Poisson process because:
#
# The number of calls is random.
#
# The calls are independent of each other.
#
# The average rate of calls (5 calls per hour) is constant.
#
# In this case, we can use the Poisson distribution to calculate the probability of receiving exactly 3 calls in one hour.
#
# Poisson Distribution Formula:
# The Poisson distribution is given by the formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝜆
# 𝑘
# 𝑒
# −
# 𝜆
# 𝑘
# !
# P(X=k)=
# k!
# λ
# k
#  e
# −λ
#
# ​
#
# Where:
#
# P(X = k) is the probability of observing k events (calls) in a fixed interval.
#
# λ (lambda) is the average rate of events (in this case, 5 calls per hour).
#
# k is the actual number of events we want to calculate the probability for (in this case, 3 calls).
#
# e is Euler's number (approximately 2.71828).
#
# Given Data:
# Average rate (λ) = 5 calls per hour
#
# Number of calls we want the probability for (k) = 3 calls
#
# Step-by-Step Calculation:
# Substitute the values into the Poisson formula:
#
# 𝑃
# (
# 𝑋
# =
# 3
# )
# =
# 5
# 3
# 𝑒
# −
# 5
# 3
# !
# P(X=3)=
# 3!
# 5
# 3
#  e
# −5
#
# ​
#
# Calculate the components:
#
# 5
# 3
# =
# 125
# 5
# 3
#  =125
#
# 𝑒
# −
# 5
# ≈
# 0.006737947
# e
# −5
#  ≈0.006737947 (approximately)
#
# 3
# !
# =
# 3
# ×
# 2
# ×
# 1
# =
# 6
# 3!=3×2×1=6
#
# Now substitute these values:
#
# 𝑃
# (
# 𝑋
# =
# 3
# )
# =
# 125
# ×
# 0.006737947
# 6
# P(X=3)=
# 6
# 125×0.006737947
# ​
#
# Calculate the probability:
#
# 𝑃
# (
# 𝑋
# =
# 3
# )
# ≈
# 0.843493375
# 6
# ≈
# 0.14058
# P(X=3)≈
# 6
# 0.843493375
# ​
#  ≈0.14058
# Result:
# The probability of receiving exactly 3 calls in one hour is approximately 0.1406 or 14.06%.
#
# Interpretation:
# In this call center scenario, there's about a 14.06% chance that exactly 3 calls will be received in the next hour, given that the average rate of calls is 5 per hour.
#
# Why the Poisson Process Fits Here:
# The number of calls is random, and it happens independently of previous calls.
#
# Calls arrive at an average rate of 5 per hour (this is the λ parameter, or average rate of events).
#
# The events (calls) happen at a constant rate over time, which fits the assumptions of a Poisson process.
#
# Applications of Poisson Processes:
# Poisson processes are used in various real-life scenarios, such as:
#
# Queuing systems: Modeling the number of customers arriving at a service desk or store.
#
# Traffic flow: Modeling the number of cars passing a specific point on a road in a given time period.
#
# Healthcare: Modeling the number of patients arriving at a hospital emergency room in a specific time interval.
#
# Natural events: Modeling the number of earthquakes or lightning strikes in a certain area during a given time frame.
#
# In all these examples, the occurrence of events is random but follows a known average rate, which is the essence of a Poisson process.

# %% [markdown]
# Q11.  Explain what a random variable is and differentiate between discrete and continuous random variables?
# - Answer What is a Random Variable?
# A random variable is a variable whose values are determined by the outcome of a random experiment or random process. It is a function that assigns numerical values to the outcomes of a random event. In simple terms, a random variable is a way of quantifying uncertainty or randomness in an experiment.
#
# For example:
#
# In a dice roll, the outcome (the number rolled) can be seen as a random variable.
#
# In an election, the number of votes a candidate receives can be seen as a random variable.
#
# Random variables can be classified into two main types: discrete and continuous.
#
# 1. Discrete Random Variable
# A discrete random variable is one that can take on a finite or countably infinite number of distinct values. These variables typically arise from counting processes.
#
# Properties of Discrete Random Variables:
# Countable outcomes: The values that the variable can take are countable. They might be finite (e.g., 1, 2, 3) or infinite but countable (e.g., 0, 1, 2, 3, ...).
#
# Finite set or countably infinite: The set of possible values is either a finite set (e.g., the number of heads in a coin toss) or an infinite but countable set (e.g., the number of people arriving at a bus stop).
#
# Examples:
#
# The number of heads in 3 coin flips (possible outcomes: 0, 1, 2, or 3 heads).
#
# The number of customers arriving at a store in an hour.
#
# The number of cars passing through a toll booth in a day.
#
# Probability Distribution of Discrete Variables:
# For a discrete random variable, its probability distribution is represented by a probability mass function (PMF), which gives the probability that the random variable takes each specific value.
#
# For example:
#
# If we roll a fair six-sided die, the random variable
# 𝑋
# X (the number rolled) can take values
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# 1,2,3,4,5,6, each with probability
# 1
# 6
# 6
# 1
# ​
#  .
#
# 2. Continuous Random Variable
# A continuous random variable is one that can take on an infinite number of values within a given range. The values are not countable because there are infinitely many of them, even between any two given values.
#
# Properties of Continuous Random Variables:
# Uncountable outcomes: The variable can take on any value within a certain interval. The set of possible values is uncountably infinite, meaning that it is not possible to list all possible values (e.g., between 0 and 1, there are infinitely many values like 0.1, 0.01, 0.001, etc.).
#
# Interval or range: The values lie within an interval or range. For example, a person's height can range between 4 and 7 feet, and there are infinitely many possible heights within that range.
#
# Examples:
#
# The height of a person (measured in inches, which can take any value within a range).
#
# The time it takes to run a race (measured to a high degree of precision, such as 12.35 seconds).
#
# The temperature on a given day (measured continuously, e.g., 25.6°C, 25.65°C, etc.).
#
# Probability Distribution of Continuous Variables:
# For continuous random variables, the probability distribution is described by a probability density function (PDF). Unlike discrete variables, the probability of a continuous random variable taking any exact value is 0 because there are infinitely many possible values. Instead, we calculate the probability that the random variable falls within a given range.
#
# For example:
#
# If we are looking at the temperature in a city, the probability that the temperature is exactly 25°C is essentially 0, but we might calculate the probability that the temperature falls between 24.5°C and 25.5°C.

# %% [markdown]
# Q12. Provide an example dataset, calculate both covariance and correlation, and interpret the results?
# - Answer Let's work through an example dataset, calculate both covariance and correlation, and then interpret the results. We'll use a simple example of height and weight of a group of individuals.
#
# Example Dataset:
# Individual	Height (in cm)	Weight (in kg)
# 1	150	50
# 2	160	55
# 3	165	58
# 4	170	60
# 5	175	65
# Step 1: Calculate the Mean of Each Variable
# First, we need to calculate the means of the height and weight.
#
# Mean of Height (
# 𝑋
# ˉ
# X
# ˉ
#  ):
# 𝑋
# ˉ
# =
# 150
# +
# 160
# +
# 165
# +
# 170
# +
# 175
# 5
# =
# 820
# 5
# =
# 164
#
# cm
# X
# ˉ
#  =
# 5
# 150+160+165+170+175
# ​
#  =
# 5
# 820
# ​
#  =164cm
# Mean of Weight (
# 𝑌
# ˉ
# Y
# ˉ
#  ):
# 𝑌
# ˉ
# =
# 50
# +
# 55
# +
# 58
# +
# 60
# +
# 65
# 5
# =
# 288
# 5
# =
# 57.6
#
# kg
# Y
# ˉ
#  =
# 5
# 50+55+58+60+65
# ​
#  =
# 5
# 288
# ​
#  =57.6kg
# Step 2: Calculate Covariance
# The covariance measures the degree to which two variables change together. A positive covariance indicates that as one variable increases, the other also increases, while a negative covariance indicates the opposite.
#
# The formula for covariance is:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# 1
# 𝑛
# −
# 1
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# Cov(X,Y)=
# n−1
# 1
# ​
#
# i=1
# ∑
# n
# ​
#  (X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  )
# Where:
#
# 𝑋
# 𝑖
# X
# i
# ​
#   and
# 𝑌
# 𝑖
# Y
# i
# ​
#   are the values of the variables (height and weight).
#
# 𝑋
# ˉ
# X
# ˉ
#   and
# 𝑌
# ˉ
# Y
# ˉ
#   are the means of the variables.
#
# 𝑛
# n is the number of data points (in this case, 5).
#
# We will now calculate the covariance step by step.
#
# Individual	Height (X)	Weight (Y)
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# X
# i
# ​
#  −
# X
# ˉ
#
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# Y
# i
# ​
#  −
# Y
# ˉ
#
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# (X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  )
# 1	150	50	-14	-7.6	106.4
# 2	160	55	-4	-2.6	10.4
# 3	165	58	1	0.4	0.4
# 4	170	60	6	2.4	14.4
# 5	175	65	11	7.4	81.4
# Now, sum up the values of
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# (X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  ):
#
# ∑
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# =
# 106.4
# +
# 10.4
# +
# 0.4
# +
# 14.4
# +
# 81.4
# =
# 213
# ∑(X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  )=106.4+10.4+0.4+14.4+81.4=213
# Now, calculate the covariance:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# 213
# 5
# −
# 1
# =
# 213
# 4
# =
# 53.25
# Cov(X,Y)=
# 5−1
# 213
# ​
#  =
# 4
# 213
# ​
#  =53.25
# Step 3: Calculate Correlation
# The correlation coefficient (denoted as r) is a standardized measure of the strength and direction of the linear relationship between two variables. The formula for the correlation coefficient is:
#
# 𝑟
# =
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# 𝜎
# 𝑋
# 𝜎
# 𝑌
# r=
# σ
# X
# ​
#  σ
# Y
# ​
#
# Cov(X,Y)
# ​
#
# Where:
#
# 𝜎
# 𝑋
# σ
# X
# ​
#   is the standard deviation of
# 𝑋
# X (height),
#
# 𝜎
# 𝑌
# σ
# Y
# ​
#   is the standard deviation of
# 𝑌
# Y (weight).
#
# 1. Calculate the Standard Deviation of Height (σₓ):
# 𝜎
# 𝑋
# =
# 1
# 𝑛
# −
# 1
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# 2
# σ
# X
# ​
#  =
# n−1
# 1
# ​
#
# i=1
# ∑
# n
# ​
#  (X
# i
# ​
#  −
# X
# ˉ
#  )
# 2
#
# ​
#
# Individual
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# X
# i
# ​
#  −
# X
# ˉ
#
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# 2
# (X
# i
# ​
#  −
# X
# ˉ
#  )
# 2
#
# 1	-14	196
# 2	-4	16
# 3	1	1
# 4	6	36
# 5	11	121
# Now, sum the squared differences:
#
# ∑
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# 2
# =
# 196
# +
# 16
# +
# 1
# +
# 36
# +
# 121
# =
# 370
# ∑(X
# i
# ​
#  −
# X
# ˉ
#  )
# 2
#  =196+16+1+36+121=370
# Now, calculate the standard deviation:
#
# 𝜎
# 𝑋
# =
# 370
# 4
# =
# 92.5
# ≈
# 9.62
# σ
# X
# ​
#  =
# 4
# 370
# ​
#
# ​
#  =
# 92.5
# ​
#  ≈9.62
# 2. Calculate the Standard Deviation of Weight (σᵧ):
# 𝜎
# 𝑌
# =
# 1
# 𝑛
# −
# 1
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# 2
# σ
# Y
# ​
#  =
# n−1
# 1
# ​
#
# i=1
# ∑
# n
# ​
#  (Y
# i
# ​
#  −
# Y
# ˉ
#  )
# 2
#
# ​
#
# Individual
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# Y
# i
# ​
#  −
# Y
# ˉ
#
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# 2
# (Y
# i
# ​
#  −
# Y
# ˉ
#  )
# 2
#
# 1	-7.6	57.76
# 2	-2.6	6.76
# 3	0.4	0.16
# 4	2.4	5.76
# 5	7.4	54.76
# Now, sum the squared differences:
#
# ∑
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# 2
# =
# 57.76
# +
# 6.76
# +
# 0.16
# +
# 5.76
# +
# 54.76
# =
# 125.2
# ∑(Y
# i
# ​
#  −
# Y
# ˉ
#  )
# 2
#  =57.76+6.76+0.16+5.76+54.76=125.2
# Now, calculate the standard deviation:
#
# 𝜎
# 𝑌
# =
# 125.2
# 4
# =
# 31.3
# ≈
# 5.59
# σ
# Y
# ​
#  =
# 4
# 125.2
# ​
#
# ​
#  =
# 31.3
# ​
#  ≈5.59
# 3. Calculate the Correlation Coefficient (r):
# 𝑟
# =
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# 𝜎
# 𝑋
# 𝜎
# 𝑌
# =
# 53.25
# 9.62
# ×
# 5.59
# =
# 53.25
# 53.74
# ≈
# 0.99
# r=
# σ
# X
# ​
#  σ
# Y
# ​
#
# Cov(X,Y)
# ​
#  =
# 9.62×5.59
# 53.25
# ​
#  =
# 53.74
# 53.25
# ​
#  ≈0.99
# Step 4: Interpret the Results
# Covariance (53.25):
# The covariance between height and weight is positive (53.25), meaning that as height increases, weight tends to increase as well. However, the magnitude of covariance doesn't provide an intuitive sense of strength because it's not normalized.
#
# Correlation (0.99):
# The correlation coefficient of 0.99 indicates a very strong positive linear relationship between height and weight. As height increases, weight tends to increase in a very consistent manner. The correlation value is very close to +1, which indicates a strong, almost perfect linear relationship.
#
# Conclusion:
# Covariance tells us that height and weight tend to increase together, but it doesn't provide a standardized measure of the strength of the relationship.
#
# Correlation provides a clearer and standardized measure of the strength and direction of the linear relationship, and in this case, the correlation is very strong (0.99), indicating that height and weight are strongly positively related.
#
# This process helps to better understand how two variables move together and provides useful insights into the strength and direction of their relationship.
